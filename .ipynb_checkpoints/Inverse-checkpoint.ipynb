# %%
dim = 512
m = 3
w = 0.2
stationary_defocus = 0.1

# %%
from speedup import generate_psf, generate_out_images, solve_inverse_implicit, solve_inverse_explicit, solve_inverse_implicit_split, recovery_quality, generate_out_images_gaussian_noise, generate_out_images_shot_noise, generate_out_images_noise
import numpy as np
import imageio
import matplotlib.pyplot as plt
import os
import time
import math

# %% [markdown]
# # Исходное изображение

# %%
src1 = imageio.imread(os.getcwd() + '/source/src_1.png')
src2 = imageio.imread(os.getcwd() + '/source/src_2.png')
src3 = imageio.imread(os.getcwd() + '/source/src_3.png')

src = np.zeros((dim, dim, m), np.double)
src[:, :, 0] = src1[:, :, 0]
src[:, :, 1] = src2[:, :, 0]
src[:, :, 2] = src3[:, :, 0]
src = src / np.amax(src)

generated_images = generate_out_images(dim, m, w, stationary_defocus, src)
out = generated_images[0]

out2 = generate_out_images_gaussian_noise(dim, m, w, stationary_defocus, src, 0.02)
out3 = generate_out_images_shot_noise(dim, m, w, stationary_defocus, src, 3000)
out4 = generate_out_images_noise(dim, m, w, stationary_defocus, src, 0.02, 3000)

# %%
from PIL import Image
im = Image.fromarray(generated_images[1][:, :, 0])
im.save("C:/Users/ulya/Documents/преддипломная практика/Обратная задача/" + "image" + ".png")

# %%
plt.imshow(np.ones((dim, dim)) - out4[0:dim,0:dim,0], cmap="Greys", interpolation='nearest')
plt.colorbar()
plt.savefig('image.png')

# %% [markdown]
# # Неявный метод

# %%
result = solve_inverse_implicit(out, dim, m, w, stationary_defocus, 1, 10)

# %%
if(np.min(result) < 0):
    result = result + abs(np.min(result))
result = result / np.max(result)

# %%
plt.imshow(np.ones((dim, dim)) - result[0:dim,0:dim,0], cmap="Greys", interpolation='nearest')
plt.colorbar()
plt.savefig('image.png')

# %%
x_plot, y_plot = recovery_quality(src[:,:,0], result[:,:,0], dim)
plt.plot(x_plot, y_plot)
plt.savefig('graph.png')

# %% [markdown]
# # Явный метод

# %%
result = solve_inverse_explicit(out, dim, m, w, 0.01, 1)

# %%
if(np.min(result) < 0):
    result = result + abs(np.min(result))
result = result / np.max(result)

# %%
plt.imshow(np.ones((512, 512)) - src[:,:,0], cmap="Greys", interpolation='nearest')
plt.colorbar()
plt.savefig('image.png')

# %%
x_plot, y_plot = recovery_quality(src[:,:,1], result[:,:,1], dim)
plt.plot(x_plot, y_plot)
plt.savefig('graph.png')

# %% [markdown]
# # Разбиение по частотам

# %%
result_split = solve_inverse_implicit_split(out, dim, m, w, 10, 10, 1, 20, 360)

# %%
if(np.min(result_split) < 0):
    result_split = result_split + abs(np.min(result_split))
result_split = result_split / np.max(result_split)

# %%
x_plot_split, y_plot_split = recovery_quality(src[:,:,0], result_split[:,:,0], dim)

# %%
result1 = solve_inverse_implicit(out, dim, m, w, 10, 10)

# %%
if(np.min(result1) < 0):
    result1 = result1 + abs(np.min(result1))
result1 = result1 / np.max(result1)

# %%
x_plot1, y_plot1 = recovery_quality(src[:,:,0], result1[:,:,0], dim)

# %%
result2 = solve_inverse_implicit(out, dim, m, w, 1, 20)

# %%
if(np.min(result2) < 0):
    result2 = result2 + abs(np.min(result2))
result2 = result2 / np.max(result2)

# %%
x_plot2, y_plot2 = recovery_quality(src[:,:,0], result2[:,:,0], dim)

# %%
plt.plot(x_plot, y_plot_split, label = "mu1 k1 mu2 k2")
plt.plot(x_plot, y_plot1, label = "mu1 k1")
plt.plot(x_plot, y_plot2, label = "mu2 k2")
plt.plot(x_plot, np.ones((dim)), label = "1")
plt.legend()
plt.savefig('graph.png')

# %% [markdown]
# # Время

# %%
from no_speedup import generate_psf2, generate_out_images2, solve_inverse_implicit2

# %%
start_time = time.time()
for i in range(10):
    generate_psf(dim, m, w, stationary_defocus)
print(time.time() - start_time)

# %%
start_time = time.time()
for i in range(10dim, m, w, stationary_defocus):
    generate_psf2(dim, m, w, stationary_defocus)
print(time.time() - start_time)

# %%
start_time = time.time()
solve_inverse_implicit(out, dim, m, w, stationary_defocus, 1, 10)
print(time.time() - start_time)

# %%
start_time = time.time()
solve_inverse_implicit2(out, dim, m, w, stationary_defocus, 10)
print(time.time() - start_time)

# %%
start_time = time.time()
for i in range(10):
    generate_out_images2(dim, m, w, stationary_defocus, src)
print(time.time() - start_time)

# %%
start_time = time.time()
for i in range(10):
    generate_out_images(dim, m, w, stationary_defocus, src)
print(time.time() - start_time)
